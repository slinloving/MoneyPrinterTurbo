# %% [markdown]
# # MoneyPrinterTurbo Setup Guide
#
# This notebook will guide you through the process of setting up [MoneyPrinterTurbo](https://github.com/harry0703/MoneyPrinterTurbo).

# %% [markdown]
# ## 1. Clone Repository and Install Dependencies
#
# First, we'll clone the repository from GitHub and install all required packages:

# %%
# !git clone https://github.com/harry0703/MoneyPrinterTurbo.git
# %cd MoneyPrinterTurbo
# !pip install -q -r requirements.txt
# !pip install pyngrok --quiet
# Out:
# Cloning into 'MoneyPrinterTurbo'...
# remote: Enumerating objects: 2336, done.
# remote: Counting objects: 100% (1380/1380), done.
# remote: Compressing objects: 100% (442/442), done.
# remote: Total 2336 (delta 973), reused 938 (delta 938), pack-reused 956 (from 1)
# Receiving objects: 100% (2336/2336), 519.70 MiB | 30.78 MiB/s, done.
# Resolving deltas: 100% (1346/1346), done.
# Updating files: 100% (115/115), done.
# /content/MoneyPrinterTurbo/MoneyPrinterTurbo

# %% [markdown]
# ## 2. Configure ngrok for Remote Access
#
# We'll use ngrok to create a secure tunnel to expose our local Streamlit server to the internet.
#
# **Important**: You need to get your authentication token from the [ngrok dashboard](https://dashboard.ngrok.com/get-started/your-authtoken) to use this service.

# %%
from pyngrok import ngrok

# Terminate any existing ngrok tunnels
ngrok.kill()

# Set your authentication token
# Replace "your_ngrok_auth_token" with your actual token
ngrok.set_auth_token("your_ngrok_auth_token")

# %% [markdown]
# ## 3. Launch Application and Generate Public URL
#
# Now we'll start the Streamlit server and create an ngrok tunnel to make it accessible online:

# %%
import subprocess
import time

print("🚀 Starting MoneyPrinterTurbo...")
# Start Streamlit server on port 8501
streamlit_proc = subprocess.Popen([
    "streamlit", "run", "./webui/Main.py", "--server.port=8501"
])

# Wait for the server to initialize
time.sleep(5)

print("🌐 Creating ngrok tunnel to expose the MoneyPrinterTurbo...")
public_url = ngrok.connect(8501, bind_tls=True)

print("✅ Deployment complete! Access your MoneyPrinterTurbo at:")
print(public_url)
# Out:
# 🚀 Starting MoneyPrinterTurbo...
# ERROR:pyngrok.process.ngrok:t=2026-03-09T07:49:14+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: your_ngrok_auth_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-03-09T07:49:14+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: your_ngrok_auth_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-03-09T07:49:14+0000 lvl=eror msg="terminating with error" obj=app err="authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: your_ngrok_auth_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# 🌐 Creating ngrok tunnel to expose the MoneyPrinterTurbo...
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipykernel_3183/2230949180.py in <cell line: 0>()
#      12
#      13 print("🌐 Creating ngrok tunnel to expose the MoneyPrinterTurbo...")
# ---> 14 public_url = ngrok.connect(8501, bind_tls=True)
#      15
#      16 print("✅ Deployment complete! Access your MoneyPrinterTurbo at:")
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     333     logger.info(f"Opening tunnel named: {name}")
#     334
# --> 335     api_url = get_ngrok_process(pyngrok_config).api_url
#     336
#     337     logger.debug(f"Creating tunnel with options: {options}")
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in get_ngrok_process(pyngrok_config)
#     200     install_ngrok(pyngrok_config)
#     201
# --> 202     return process.get_process(pyngrok_config)
#     203
#     204
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/process.py in get_process(pyngrok_config)
#     269         return _current_processes[pyngrok_config.ngrok_path]
#     270
# --> 271     return _start_process(pyngrok_config)
#     272
#     273
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/process.py in _start_process(pyngrok_config)
#     445
#     446         if ngrok_process.startup_error is not None:
# --> 447             raise PyngrokNgrokError(f"The ngrok process errored on start: {ngrok_process.startup_error}.",
#     448                                     ngrok_process.logs,
#     449                                     ngrok_process.startup_error)
#
# PyngrokNgrokError: The ngrok process errored on start: authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: your_ngrok_auth_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n.
